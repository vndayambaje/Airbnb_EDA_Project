# %% [markdown]
# # Essential Questions to Answer
# 1. What rental features (amenities, house rules) lead to higher customer ratings and fetch higher rental income?
# 2. What are the features of high-demand properties? (75th, 80th percentile -> )
# 3. Are higher-income properties close to big cities, beaches, or tourist attractions?
# 4. Which countries have the top Airbnb ratings and reviews?

# %%
import pandas as pd
import requests

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
# Load the data
df = pd.read_csv('airbnb_clean.csv')

# Display the first few rows
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#          id                                               name  rating  \
# 0  49849504                                     Perla bungalov    4.71
# 1  50891766  Authentic Beach Architect Sheltered Villa with...   -1.00
# 2  50699164                                  cottages sataplia    4.85
# 3  49871422                        Sapanca Breathable Bungalow    5.00
# 4  51245886                                      Bungalov Ev 2   -1.00
#
#    reviews    host_id                   address    price   country  bathrooms  \
# 0       64  357334205  Kartepe, Kocaeli, Turkey  8078.00    Turkey          1
# 1        0  386223873      Kaş, Antalya, Turkey  4665.00    Turkey          2
# 2       68  409690853          Imereti, Georgia  5991.00   Georgia          1
# 3       13  401873242  Sapanca, Sakarya, Turkey 11339.00    Turkey          1
# 4        0  414884116  Sapanca, Sakarya, Turkey  6673.00    Turkey          1
#
#    beds  guests  toilets  bedrooms  studios              checkin   checkout  \
# 0     1       2        0         2        0             Flexible   12 00 pm
# 1     2       4        0         2        0   4 00 pm - 11 00 pm   10 00 am
# 2     3       4        0         1        0        After 1 00 pm   12 00 pm
# 3     2       4        0         1        0        After 2 00 pm   12 00 pm
# 4     1       2        0         1        0        After 2 00 pm   12 00 pm
#
#    usd_price    tv  wifi  chromecast  refrigerator  kitchen   view  parking  \
# 0     244.14  True  True       False         False     True   True     True
# 1     140.99  True  True       False         False     True  False     True
# 2        NaN  True  True       False         False     True   True     True
# 3     342.70  True  True       False         False     True   True     True
# 4     201.68  True  True       False         False     True  False     True
#
#    workspace   pool    gym  no_pets  no_smoking  no_parties_or_events  \
# 0      False  False  False    False       False                 False
# 1       True   True  False     True        True                  True
# 2       True  False  False    False       False                 False
# 3      False   True  False     True        True                 False
# 4      False  False  False     True        True                  True
#
#    house_rules_num  img_links_num  amenities_num
# 0                5              6             10
# 1                5              6             10
# 2                4              6             10
# 3                4              6             10
# 4                8              6              8

# %%
countries_with_nan_usd_price = df[df['usd_price'].isna()]['country'].unique()
countries_with_nan_usd_price
# Out:
# array([' Georgia', ' Vietnam', ' Lebanon', ' Taiwan', ' Armenia',
#        ' Ukraine', ' Albania', ' Tanzania', ' Sri Lanka',
#        ' Bosnia and Herzegovina', ' Kenya', ' Serbia', ' Seychelles',
#        ' Morocco', ' Egypt', ' United Arab Emirates', ' Pakistan',
#        ' Nepal', 'Sri Lanka', ' Cambodia', ' Azerbaijan', ' Costa Rica',
#        ' Panama', ' Peru', ' Chile', ' Belize', 'Panama', ' Colombia',
#        ' Bolivia', ' Mauritius', ' Fiji', ' Maldives', 'Serbia',
#        ' Myanmar', ' Brunei Darussalam', ' Kyrgyzstan', ' Uruguay',
#        ' Argentina', ' Bahamas', ' Oman', ' Kuwait', ' Saudi Arabia',
#        ' Kazakhstan', ' Uganda', 'Maldives', ' Qatar', ' Jordan', 'Egypt',
#        ' Bangladesh', ' Mongolia', ' Uzbekistan', ' Rwanda', ' Honduras',
#        ' Nicaragua', ' Vanuatu', 'Belize', ' Cayman Islands',
#        ' French Polynesia', ' Jamaica', ' Madagascar', 'Jordan',
#        'Georgia', 'Taiwan', 'Saudi Arabia', ' Tunisia',
#        ' Congo Republic of the Democratic', ' Cuba', 'Cuba', ' Nigeria',
#        ' Saint Martin (French part)', ' Guatemala', ' Senegal', 'Morocco',
#        ' Namibia'], dtype=object)

# %%
def get_exchange_rates(base_currency='USD'):
    url = 'https://api.exchangerate-api.com/v4/latest/' + base_currency
    response = requests.get(url)
    data = response.json()
    return data['rates']

# Fetch exchange rates
exchange_rates = get_exchange_rates()

# Define currency codes for the countries of interest
currency_codes = {
    'Georgia': 'GEL',
    'Vietnam': 'VND',
    'Lebanon': 'LBP',
    'Taiwan': 'TWD',
    'Armenia': 'AMD',
    'Ukraine': 'UAH',
    'Albania': 'ALL',
    'Tanzania': 'TZS',
    'Sri Lanka': 'LKR',
    'Bosnia and Herzegovina': 'BAM',
    'Kenya': 'KES',
    'Serbia': 'RSD',
    'Seychelles': 'SCR',
    'Morocco': 'MAD',
    'Egypt': 'EGP',
    'United Arab Emirates': 'AED',
    'Pakistan': 'PKR',
    'Nepal': 'NPR',
    'Cambodia': 'KHR',
    'Azerbaijan': 'AZN',
    'Costa Rica': 'CRC',
    'Panama': 'PAB',
    'Peru': 'PEN',
    'Chile': 'CLP',
    'Belize': 'BZD',
    'Colombia': 'COP',
    'Bolivia': 'BOB',
    'Mauritius': 'MUR',
    'Fiji': 'FJD',
    'Maldives': 'MVR',
    'Myanmar': 'MMK',
    'Brunei Darussalam': 'BND',
    'Kyrgyzstan': 'KGS',
    'Uruguay': 'UYU',
    'Argentina': 'ARS',
    'Bahamas': 'BSD',
    'Oman': 'OMR',
    'Kuwait': 'KWD',
    'Saudi Arabia': 'SAR',
    'Kazakhstan': 'KZT',
    'Uganda': 'UGX',
    'Qatar': 'QAR',
    'Jordan': 'JOD',
    'Bangladesh': 'BDT',
    'Mongolia': 'MNT',
    'Uzbekistan': 'UZS',
    'Rwanda': 'RWF',
    'Honduras': 'HNL',
    'Nicaragua': 'NIO',
    'Vanuatu': 'VUV',
    'Cayman Islands': 'KYD',
    'French Polynesia': 'XPF',
    'Jamaica': 'JMD',
    'Madagascar': 'MGF',
    'Tunisia': 'TND',
    'Congo Republic of the Democratic': 'CDF',
    'Cuba': 'CUP',
    'Nigeria': 'NGN',
    'Saint Martin (French part)': 'EUR',
    'Guatemala': 'GTQ',
    'Senegal': 'XOF',
    'Namibia': 'NAD'
}

# Convert to USD
conversion_rates = {}
for country, currency in currency_codes.items():
    if currency in exchange_rates:
        conversion_rates[country] = 1/exchange_rates[currency]
    else:
        conversion_rates[country] = None
        print(f"Currency rate for {currency} not found.")

print(conversion_rates)
conversion_rates['Madagascar'] = 0.0000440133
# Out:
# Currency rate for MGF not found.
# {'Georgia': 0.3676470588235294, 'Vietnam': 3.959248249616349e-05, 'Lebanon': 1.11731843575419e-05, 'Taiwan': 0.03045994517209869, 'Armenia': 0.0025775188803257984, 'Ukraine': 0.024372410431391663, 'Albania': 0.010796804145972791, 'Tanzania': 0.00037250052150073013, 'Sri Lanka': 0.0033077533739084416, 'Bosnia and Herzegovina': 0.5524861878453039, 'Kenya': 0.0076663600122661765, 'Serbia': 0.009240436148586214, 'Seychelles': 0.07513148009015777, 'Morocco': 0.10080645161290323, 'Egypt': 0.020656889072505683, 'United Arab Emirates': 0.2724795640326976, 'Pakistan': 0.003587701359738815, 'Nepal': 0.007462686567164179, 'Cambodia': 0.0002420926488567175, 'Azerbaijan': 0.5882352941176471, 'Costa Rica': 0.0018964895977545565, 'Panama': 1.0, 'Peru': 0.267379679144385, 'Chile': 0.001045609485769255, 'Belize': 0.5, 'Colombia': 0.00024558559886048284, 'Bolivia': 0.14430014430014432, 'Mauritius': 0.021468441391155002, 'Fiji': 0.4424778761061947, 'Maldives': 0.0648508430609598, 'Myanmar': 0.0004767921424654922, 'Brunei Darussalam': 0.7462686567164178, 'Kyrgyzstan': 0.011872254541137361, 'Uruguay': 0.024795437639474338, 'Argentina': 0.0010726736390453205, 'Bahamas': 1.0, 'Oman': 2.6041666666666665, 'Kuwait': 3.2679738562091503, 'Saudi Arabia': 0.26666666666666666, 'Kazakhstan': 0.0021077480819492456, 'Uganda': 0.00026847871903433576, 'Qatar': 0.2747252747252747, 'Jordan': 1.4104372355430184, 'Bangladesh': 0.00851063829787234, 'Mongolia': 0.0002957739813544082, 'Uzbekistan': 7.974068329791518e-05, 'Rwanda': 0.0007571512939715614, 'Honduras': 0.04033884630899556, 'Nicaragua': 0.027137042062415195, 'Vanuatu': 0.008306337735692334, 'Cayman Islands': 1.2004801920768309, 'French Polynesia': 0.009063717937097798, 'Jamaica': 0.00638895987733197, 'Madagascar': None, 'Tunisia': 0.3225806451612903, 'Congo Republic of the Democratic': 0.0003535642815220235, 'Cuba': 0.041666666666666664, 'Nigeria': 0.0006196132374172041, 'Saint Martin (French part)': 1.081081081081081, 'Guatemala': 0.1288659793814433, 'Senegal': 0.0016488589895792111, 'Namibia': 0.05455537370430988}

# %%
def convert_curr(row):
  country = row['country'].strip()
  # print("'"+country+"'")
  # print(country in conversion_rates)
  if country in conversion_rates:
    return row.price * conversion_rates[country]
  else:
    return row.usd_price

df['usd_price'] = df.apply(lambda row: convert_curr(row), axis=1)
df.head()
# Out:
#          id                                               name  rating  \
# 0  49849504                                     Perla bungalov    4.71
# 1  50891766  Authentic Beach Architect Sheltered Villa with...   -1.00
# 2  50699164                                  cottages sataplia    4.85
# 3  49871422                        Sapanca Breathable Bungalow    5.00
# 4  51245886                                      Bungalov Ev 2   -1.00
#
#    reviews    host_id                   address    price   country  bathrooms  \
# 0       64  357334205  Kartepe, Kocaeli, Turkey  8078.00    Turkey          1
# 1        0  386223873      Kaş, Antalya, Turkey  4665.00    Turkey          2
# 2       68  409690853          Imereti, Georgia  5991.00   Georgia          1
# 3       13  401873242  Sapanca, Sakarya, Turkey 11339.00    Turkey          1
# 4        0  414884116  Sapanca, Sakarya, Turkey  6673.00    Turkey          1
#
#    beds  guests  toilets  bedrooms  studios              checkin   checkout  \
# 0     1       2        0         2        0             Flexible   12 00 pm
# 1     2       4        0         2        0   4 00 pm - 11 00 pm   10 00 am
# 2     3       4        0         1        0        After 1 00 pm   12 00 pm
# 3     2       4        0         1        0        After 2 00 pm   12 00 pm
# 4     1       2        0         1        0        After 2 00 pm   12 00 pm
#
#    usd_price    tv  wifi  chromecast  refrigerator  kitchen   view  parking  \
# 0     244.14  True  True       False         False     True   True     True
# 1     140.99  True  True       False         False     True  False     True
# 2    2202.57  True  True       False         False     True   True     True
# 3     342.70  True  True       False         False     True   True     True
# 4     201.68  True  True       False         False     True  False     True
#
#    workspace   pool    gym  no_pets  no_smoking  no_parties_or_events  \
# 0      False  False  False    False       False                 False
# 1       True   True  False     True        True                  True
# 2       True  False  False    False       False                 False
# 3      False   True  False     True        True                 False
# 4      False  False  False     True        True                  True
#
#    house_rules_num  img_links_num  amenities_num
# 0                5              6             10
# 1                5              6             10
# 2                4              6             10
# 3                4              6             10
# 4                8              6              8

# %% [markdown]
# Moved all the code to add usd dollars back to the main "Project_2_code notebook"

# %%
# restart notebook to use aribnb_clean_2.csv
df = pd.read_csv('airbnb_clean_2.csv')
df = df.loc[df['rating'] != -1]
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute correlation matrix
corr = df[['rating', 'usd_price', 'tv', 'wifi', 'chromecast', 'refrigerator', 'kitchen', 'view', 
           'parking', 'workspace', 'pool', 'gym', 'no_pets', 'no_smoking', 'no_parties_or_events', 
           'house_rules_num', 'amenities_num']].corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation between Rental Features and Ratings/price')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# Prepare feature matrix and target vector
features = ['tv', 'wifi', 'chromecast', 'refrigerator', 'kitchen', 'view', 
            'parking', 'workspace', 'pool', 'gym', 'no_pets', 'no_smoking', 
            'no_parties_or_events']
X = df[features].fillna(0)  # Fill missing values
y_rating = df['rating'].fillna(df['rating'].mean())  # Handle missing ratings
y_price = df['usd_price'].fillna(df['usd_price'].mean())  # Handle missing price

# Fit Random Forest model for ratings
rf_rating = RandomForestRegressor(n_estimators=100)
rf_rating.fit(X, y_rating)

# Fit Random Forest model for price
rf_price = RandomForestRegressor(n_estimators=100)
rf_price.fit(X, y_price)

# Get feature importances
importance_rating = rf_rating.feature_importances_
importance_price = rf_price.feature_importances_

# Create DataFrame for feature importances
importance_df_rating = pd.DataFrame({'Feature': features, 'Importance': importance_rating})
importance_df_price = pd.DataFrame({'Feature': features, 'Importance': importance_price})

# Plot feature importances
plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=importance_df_rating.sort_values(by='Importance', ascending=False))
plt.title('Feature Importance for Ratings')
plt.show()

plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=importance_df_price.sort_values(by='Importance', ascending=False))
plt.title('Feature Importance for Rental price')
plt.show()

# %% [markdown]
# question: are the listings who charge more get traction?

# %%
# Define high-demand properties
high_demand_threshold = df['reviews'].quantile(0.75)
high_demand_properties = df[df['reviews'] >= high_demand_threshold]
high_demand_properties
# Out:
#              id                                               name  rating  \
# 2      50699164                                  cottages sataplia    4.85
# 10     50425621  A private pension hut on the hillside of Sokli...    4.97
# 12     50689801  Cabin A Pahimis - private w/ pool & kitchen for 8    4.83
# 29     22606080                   Coconut Tree House Udalo Mindoro    4.87
# 39     21082489                               LOGIN OKINAWA -wood-    4.68
# ...         ...                                                ...     ...
# 12724  45696168       HAIN GLAMP - A unique place in the mountains    4.96
# 12731  23581739                                  Narvik Adventures    4.85
# 12735  36611802    Ocean Front！UrumaDome【SPRING SALE】MK058~MK066UP    4.83
# 12746  26690381  (Private house) Wifi/Vivaldi 10 minutes by car...    4.88
# 12757   7506968                               Pachamama Pool Villa    4.83
#
#        reviews    host_id                                            address  \
# 2           68  409690853                                   Imereti, Georgia
# 10          77   81358542  Sanoe-myeon, Boeun-gun, North Chungcheong Prov...
# 12         116   33615391                    Amadeo, Calabarzon, Philippines
# 29          85   23070428                Abra de Ilog, MIMAROPA, Philippines
# 39         241  151975076         Onna-son, Kunigami-gun, Okinawa-ken, Japan
# ...        ...        ...                                                ...
# 12724       81  370269432                    Przesieka, Dolnośląskie, Poland
# 12731       67  176256646                           Narvik, Nordland, Norway
# 12735      272   89004316                                   うるま市, 沖縄県, Japan
# 12746      141  158370988                              양평군, 경기도, South Korea
# 12757       96   39326711           Gili Air, Nusa Tenggara Barat, Indonesia
#
#          price       country  bathrooms  beds  guests  toilets  bedrooms  \
# 2      5991.00       Georgia          1     3       4        0         1
# 10     9052.00   Korea South          1     1       4        0         1
# 12    14612.00   Philippines          2     7       8        0         2
# 29     1372.00   Philippines          1     1       2        0         1
# 39    13010.00         Japan          1     7       9        0         3
# ...        ...           ...        ...   ...     ...      ...       ...
# 12724  9517.00        Poland          1     2       3        0         1
# 12731 21020.00        Norway          1     4       4        0         1
# 12735 12590.00         Japan          1     2       4        0         1
# 12746 12894.00   Korea South          2     1       5        0         1
# 12757 12323.00     Indonesia          1     2       4        0         2
#
#        studios              checkin   checkout  usd_price     tv   wifi  \
# 2            0        After 1 00 pm   12 00 pm    2202.57   True   True
# 10           0    3 00 pm - 9 00 pm   11 00 am       6.55  False  False
# 12           0    2 00 pm - 4 00 pm   12 00 pm     250.59  False   True
# 29           0             Flexible   Flexible      23.53  False  False
# 39           0   4 00 pm - 12 00 am   11 00 am      83.15   True   True
# ...        ...                  ...        ...        ...    ...    ...
# 12724        0        After 3 00 pm   11 00 am    2423.71   True   True
# 12731        0        After 2 00 pm   12 00 pm    1955.64   True  False
# 12735        0        After 4 00 pm   11 00 am      80.46   True   True
# 12746        0        After 2 00 pm   11 00 am       9.32   True   True
# 12757        0        After 1 00 pm   11 00 am       0.76   True   True
#
#        chromecast  refrigerator  kitchen   view  parking  workspace   pool  \
# 2           False         False     True   True     True       True  False
# 10          False          True     True   True     True      False  False
# 12          False          True     True  False     True       True   True
# 29          False          True     True  False    False      False  False
# 39          False         False     True   True     True      False  False
# ...           ...           ...      ...    ...      ...        ...    ...
# 12724       False         False     True  False     True      False  False
# 12731       False         False     True  False     True      False  False
# 12735       False         False     True   True    False       True  False
# 12746       False         False     True   True     True      False  False
# 12757        True         False     True   True     True       True   True
#
#          gym  no_pets  no_smoking  no_parties_or_events  house_rules_num  \
# 2      False    False       False                 False                4
# 10     False     True        True                  True                6
# 12     False     True       False                  True               10
# 29     False    False        True                 False                3
# 39     False    False        True                  True                9
# ...      ...      ...         ...                   ...              ...
# 12724  False     True        True                  True                9
# 12731  False    False        True                 False                5
# 12735  False     True        True                  True                9
# 12746  False    False       False                 False                9
# 12757  False    False        True                 False                7
#
#        img_links_num  amenities_num
# 2                  6             10
# 10                 7              9
# 12                 9             10
# 29                 6              9
# 39                 6             10
# ...              ...            ...
# 12724              6             10
# 12731              6             10
# 12735              7             10
# 12746              6             10
# 12757              8             10
#
# [2147 rows x 33 columns]

# %%
# Compute mean features for high-demand properties
high_demand_features = high_demand_properties[features].mean()

# Compare with overall mean features
overall_features = df[features].mean()

# Create DataFrame for comparison
comparison_df = pd.DataFrame({
    'Feature': features,
    'High Demand Mean': high_demand_features,
    'Overall Mean': overall_features
})

# Plot comparison
comparison_df.plot(x='Feature', kind='bar', figsize=(12, 8))
plt.title('Comparison of Features for High-Demand Properties')
plt.show()

# %%
country_summary = df.groupby('country').agg({'rating': 'mean', 'reviews': 'sum'}).reset_index()
country_summary = country_summary.sort_values(by=['rating', 'reviews'], ascending=[False, False])

country_summary
# Out:
#                 country  rating  reviews
# 2               Armenia    5.00       30
# 64              Myanmar    5.00       20
# 130           Sri Lanka    5.00       16
# 126            Portugal    5.00       15
# 109              Belize    5.00       12
# ..                  ...     ...      ...
# 105             Uruguay    4.62       13
# 131              Taiwan    4.58       12
# 11    Brunei Darussalam    4.57        7
# 120              Jordan    4.50        4
# 5               Bahamas    4.00       30
#
# [135 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# Data preparation
top20_ratings = country_summary.sort_values(by='rating', ascending=False).head(20)
top20_reviews = country_summary.sort_values(by='reviews', ascending=False).head(20)

# Plot for Average Rating by Country with Number of Reviews Annotation
plt.figure(figsize=(14, 7))
bars = plt.barh(top20_ratings['country'], top20_ratings['rating'], color='lightblue')
plt.title('Average Rating by Country')
plt.xlabel('Average Rating')
plt.ylabel('Country')
plt.gca().invert_yaxis()  # Invert the y-axis to have the highest rating at the top

# Annotating each bar with the number of reviews
for bar, reviews in zip(bars, top20_ratings['reviews']):
    plt.text(
        bar.get_width() + 0.02 * bar.get_width(),  # Adjust position relative to bar width
        bar.get_y() + bar.get_height() / 2, 
        f'{reviews}', 
        va='center', 
        ha='left'
    )

plt.tight_layout()
plt.show()

# Plot for Total Reviews by Country with Average Ratings Annotation
plt.figure(figsize=(14, 7))
bars = plt.barh(top20_reviews['country'], top20_reviews['reviews'], color='lightblue')
plt.title('Total Reviews by Country')
plt.xlabel('Total Reviews')
plt.ylabel('Country')
plt.gca().invert_yaxis()  # Invert the y-axis to have the most reviews at the top

# Annotating each bar with the average rating
for bar, rating in zip(bars, top20_reviews['rating']):
    plt.text(
        bar.get_width() + 0.02 * bar.get_width(),  # Adjust position relative to bar width
        bar.get_y() + bar.get_height() / 2, 
        f'{rating:.2f}', 
        va='center', 
        ha='left'
    )

plt.tight_layout()
plt.show()

# %%
df.loc[df['country'] == ' United States']
# Out:
#        Unnamed: 0        id  \
# 308           308  21401089
# 332           332  52202835
# 359           359  31314964
# 517           517  52311422
# 522           522  13769501
# ...           ...       ...
# 10843       10843  48082462
# 10850       10850  49140582
# 10854       10854  23687132
# 10856       10856  12604546
# 10860       10860   1752714
#
#                                                     name  rating  reviews  \
# 308                                    Borealis Basecamp    4.85       23
# 332    River Rest 1: Brand new, on river, prime locat...    4.93       44
# 359      Aurora Villa 御墅极光 D2B(1)Deluxe double bed  Room    4.86       14
# 517                          Life’s Better on the River!    4.97       72
# 522                                  Eskimo Kisses Cabin    4.61      246
# ...                                                  ...     ...      ...
# 10843                Micro Music Studio - Workspace Only    5.00        7
# 10850                       🏳️‍🌈🍁 arthouse 1312 - room 3    4.83       48
# 10854       Historic upscale artist loft on the Beltline    4.98       52
# 10856              Spacious, Comfy, Close to Everything!    4.99      133
# 10860                BeverlyHills private Townhouse room    4.93       27
#
#          host_id                                   address    price  \
# 308    103402123          Fairbanks, Alaska, United States 35479.00
# 332    105112930          Fairbanks, Alaska, United States 16608.00
# 359    234392519          Fairbanks, Alaska, United States 53629.00
# 517     56795945          Fairbanks, Alaska, United States 21522.00
# 522     80784949          Fairbanks, Alaska, United States 10658.00
# ...          ...                                       ...      ...
# 10843   25928187       North Miami, Florida, United States 19866.00
# 10850   34850487             Tempe, Arizona, United States  5025.00
# 10854   88334116           Atlanta, Georgia, United States 20651.00
# 10856   68399601       Nashville, Tennessee, United States 48873.00
# 10860    9219889  Beverly Hills, California, United States 16268.00
#
#               country  bathrooms  beds  guests  toilets  bedrooms  studios  \
# 308     United States          1     1       2        0         1        0
# 332     United States          1     1       2        0         1        0
# 359     United States          1     1       4        0         1        0
# 517     United States          1     3       5        0         2        0
# 522     United States          1     3       8        0         1        0
# ...               ...        ...   ...     ...      ...       ...      ...
# 10843   United States          0     1       1        0         0        0
# 10850   United States          1     1       1        0         1        0
# 10854   United States          1     1       3        0         1        0
# 10856   United States          2     3       8        0         3        0
# 10860   United States          1     1       2        0         1        0
#
#                    checkin   checkout  usd_price     tv   wifi  chromecast  \
# 308      4 00 pm - 1 00 am   12 00 pm   35479.00  False  False       False
# 332          After 3 00 pm   11 00 am   16608.00   True   True       False
# 359     3 00 pm - 12 00 am   11 00 am   53629.00   True   True       False
# 517          After 3 00 pm   11 00 am   21522.00   True   True       False
# 522          After 4 00 pm   11 00 am   10658.00   True   True       False
# ...                    ...        ...        ...    ...    ...         ...
# 10843    4 00 pm - 7 00 pm    1 00 am   19866.00   True   True       False
# 10850             Flexible   10 00 am    5025.00   True   True       False
# 10854        After 3 00 pm   11 00 am   20651.00   True   True       False
# 10856        After 3 00 pm   11 00 am   48873.00   True   True       False
# 10860             Flexible   Flexible   16268.00  False   True       False
#
#        refrigerator  kitchen   view  parking  workspace   pool    gym  \
# 308           False    False  False     True      False  False  False
# 332           False     True   True     True       True  False  False
# 359           False    False  False     True      False  False  False
# 517           False     True   True     True      False  False  False
# 522           False     True  False     True      False  False  False
# ...             ...      ...    ...      ...        ...    ...    ...
# 10843         False    False  False     True       True  False  False
# 10850         False     True  False     True       True  False  False
# 10854         False     True  False     True       True  False  False
# 10856         False     True  False     True       True  False  False
# 10860         False     True   True     True      False  False  False
#
#        no_pets  no_smoking  no_parties_or_events  house_rules_num  \
# 308       True        True                 False                7
# 332       True        True                  True               10
# 359       True        True                  True                9
# 517       True        True                 False                9
# 522       True        True                  True                9
# ...        ...         ...                   ...              ...
# 10843     True        True                  True               10
# 10850     True        True                  True               10
# 10854     True        True                  True                9
# 10856     True        True                  True               10
# 10860     True        True                  True                8
#
#        img_links_num  amenities_num
# 308                7              7
# 332                6             10
# 359                6              7
# 517                6             11
# 522                7             10
# ...              ...            ...
# 10843              6              9
# 10850              6             10
# 10854              6             14
# 10856              9             10
# 10860              6             10
#
# [176 rows x 34 columns]

# %%
def extract_city(address):
    # Split the address by comma
    parts = address.split(',')
    # Check if there are enough parts
    if len(parts) > 1:
        # Return the city part (assuming city is the first part)
        return parts[0].strip()
    return None

# Apply the function to create a new column for the city
df['city'] = df['address'].apply(extract_city)

df
# Out:
#        Unnamed: 0        id  \
# 0               0  49849504
# 2               2  50699164
# 3               3  49871422
# 9               9  42075682
# 10             10  50425621
# ...           ...       ...
# 12800       12800  44697740
# 12801       12801  29975283
# 12802       12802  32977697
# 12803       12803   8006146
# 12804       12804  40547903
#
#                                                     name  rating  reviews  \
# 0                                         Perla bungalov    4.71       64
# 2                                      cottages sataplia    4.85       68
# 3                            Sapanca Breathable Bungalow    5.00       13
# 9                        The Cottage, Private Pool Villa    4.67        3
# 10     A private pension hut on the hillside of Sokli...    4.97       77
# ...                                                  ...     ...      ...
# 12800            Brown Dome House No. 3, full of healing    4.94       16
# 12801       Bubble Hotel Ubud with Bathtub under the Sky    4.67        6
# 12802                                   Paradise Eco Hub    4.67        3
# 12803     WisDOME - Mentigi Bay Village - Gilis - Lombok    4.86        7
# 12804   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]    4.85       13
#
#          host_id                                            address    price  \
# 0      357334205                           Kartepe, Kocaeli, Turkey  8078.00
# 2      409690853                                   Imereti, Georgia  5991.00
# 3      401873242                           Sapanca, Sakarya, Turkey 11339.00
# 9      173126583  Tambon Bang Kachai, Chang Wat Chanthaburi, Tha... 30486.00
# 10      81358542  Sanoe-myeon, Boeun-gun, North Chungcheong Prov...  9052.00
# ...          ...                                                ...      ...
# 12800  161552316  Imhoe-myeon, Jindo, South Jeolla Province, Sou...  4288.00
# 12801  118954227                                 Gianyar, Indonesia 15200.00
# 12802  175214568                                     Kabale, Uganda  9103.00
# 12803     718423        Gunung Sari, Nusa Tenggara Barat, Indonesia 42262.00
# 12804  246470880                              Uruma, Okinawa, Japan  9909.00
#
#             country  bathrooms  beds  guests  toilets  bedrooms  studios  \
# 0            Turkey          1     1       2        0         2        0
# 2           Georgia          1     3       4        0         1        0
# 3            Turkey          1     2       4        0         1        0
# 9          Thailand          3     6      10        0         4        0
# 10      Korea South          1     1       4        0         1        0
# ...             ...        ...   ...     ...      ...       ...      ...
# 12800   Korea South          8     0       4        0         0        0
# 12801     Indonesia          0     1       2        1         1        0
# 12802        Uganda          1     2       2        0         1        0
# 12803     Indonesia          2     4       8        0         2        0
# 12804         Japan          1     2       5        0         1        0
#
#                    checkin   checkout  usd_price     tv   wifi  chromecast  \
# 0                 Flexible   12 00 pm     244.14   True   True       False
# 2            After 1 00 pm   12 00 pm    2202.57   True   True       False
# 3            After 2 00 pm   12 00 pm     342.70   True   True       False
# 9            After 3 00 pm   Flexible     847.89   True   True       False
# 10       3 00 pm - 9 00 pm   11 00 am       6.55  False  False       False
# ...                    ...        ...        ...    ...    ...         ...
# 12800   3 00 pm - 11 00 pm   11 00 am       3.10   True   True       False
# 12801   3 00 pm - 10 00 pm   12 00 pm       0.94  False   True       False
# 12802        After 3 00 pm   Flexible       2.44  False   True       False
# 12803             Flexible   12 00 pm       2.61  False   True       False
# 12804        After 4 00 pm   11 00 am      63.33   True   True       False
#
#        refrigerator  kitchen   view  parking  workspace   pool    gym  \
# 0             False     True   True     True      False  False  False
# 2             False     True   True     True       True  False  False
# 3             False     True   True     True      False   True  False
# 9             False     True  False     True      False   True  False
# 10             True     True   True     True      False  False  False
# ...             ...      ...    ...      ...        ...    ...    ...
# 12800         False     True  False     True      False   True  False
# 12801         False    False  False     True      False  False  False
# 12802         False    False  False    False      False  False  False
# 12803         False     True  False     True       True   True  False
# 12804         False     True   True     True       True  False  False
#
#        no_pets  no_smoking  no_parties_or_events  house_rules_num  \
# 0        False       False                 False                5
# 2        False       False                 False                4
# 3         True        True                 False                4
# 9         True        True                 False                3
# 10        True        True                  True                6
# ...        ...         ...                   ...              ...
# 12800    False        True                 False                4
# 12801     True        True                  True                5
# 12802    False       False                 False                1
# 12803     True       False                 False                8
# 12804     True        True                  True                9
#
#        img_links_num  amenities_num                city
# 0                  6             10             Kartepe
# 2                  6             10             Imereti
# 3                  6             10             Sapanca
# 9                  6              9  Tambon Bang Kachai
# 10                 7              9         Sanoe-myeon
# ...              ...            ...                 ...
# 12800              6             10         Imhoe-myeon
# 12801              6              8             Gianyar
# 12802              6              5              Kabale
# 12803              6             10         Gunung Sari
# 12804              6             10               Uruma
#
# [8567 rows x 35 columns]

# %%
# ! pip install geopy geopandas shapely
# from geopy.geocoders import Nominatim
# import geopandas as gpd
# from shapely.geometry import Point

# # Initialize geolocator
# geolocator = Nominatim(user_agent="geoapiExercises")

# # Function to get coordinates from city
# def get_coordinates(city):
#     try:
#         location = geolocator.geocode(city)
#         if location:
#             return (location.latitude, location.longitude)
#     except:
#         return None
#     return None

# # Apply function to get coordinates
# df['coordinates'] = df['city'].apply(get_coordinates)

# # Split coordinates into separate columns
# df[['latitude', 'longitude']] = pd.DataFrame(df['coordinates'].tolist(), index=df.index)

# %%
# # Drop rows where coordinates are missing
# df = df.dropna(subset=['latitude', 'longitude'])

# # Create GeoDataFrame
# geometry = [Point(xy) for xy in zip(df['longitude'], df['latitude'])]
# gdf = gpd.GeoDataFrame(df, geometry=geometry)

# # Set the coordinate reference system (CRS) to WGS84 (common for GPS coordinates)
# gdf.set_crs(epsg=4326, inplace=True)
