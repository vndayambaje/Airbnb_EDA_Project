# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\rs_mi\Downloads\airbnb.csv")
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
# 2           2  50699164                                  cottages sataplia
# 3           3  49871422                        Sapanca Breathable Bungalow
# 4           4  51245886                                      Bungalov Ev 2
#
#   rating reviews    host_name      host_id                   address  \
# 0   4.71      64    Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1    New       0        Fatih  386223873.0      Kaş, Antalya, Turkey
# 2   4.85      68       Giorgi  409690853.0          Imereti, Georgia
# 3    5.0      13        Melih  401873242.0  Sapanca, Sakarya, Turkey
# 4    New       0  Arp Sapanca  414884116.0  Sapanca, Sakarya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# ...

# %%
df.shape
# Out:
# (12805, 23)

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# id                int64
# name             object
# rating           object
# reviews          object
# host_name        object
# host_id         float64
# address          object
# features         object
# amenities        object
# safety_rules     object
# hourse_rules     object
# img_links        object
# price             int64
# country          object
# bathrooms         int64
# beds              int64
# guests            int64
# toiles            int64
# bedrooms          int64
# studios           int64
# checkin          object
# checkout         object
# dtype: object

# %%
df.describe()
# Out:
#          Unnamed: 0            id       host_id         price     bathrooms  \
# count  12805.000000  1.280500e+04  1.280500e+04  1.280500e+04  12805.000000
# mean    6402.000000  7.525187e+16  1.638192e+08  1.769780e+04      1.874424
# std     3696.629433  2.007933e+17  1.413622e+08  4.569364e+04      2.091399
# min        0.000000  1.313100e+04  2.303900e+04  3.930000e+02      0.000000
# 25%     3201.000000  2.023958e+07  3.700032e+07  3.994000e+03      1.000000
# 50%     6402.000000  3.682229e+07  1.256459e+08  8.175000e+03      1.000000
# 75%     9603.000000  4.999760e+07  2.639623e+08  1.606200e+04      2.000000
# max    12804.000000  7.017905e+17  4.758973e+08  1.907963e+06     50.000000
#
#                beds        guests        toiles      bedrooms       studios
# count  12805.000000  12805.000000  12805.000000  12805.000000  12805.000000
# mean       3.316751      5.213745      0.019211      2.136041      0.023585
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# id                 0
# name               0
# rating             0
# reviews            0
# host_name          8
# host_id            0
# address            0
# features           0
# amenities          0
# safety_rules       0
# hourse_rules       0
# img_links          0
# price              0
# country            0
# bathrooms          0
# beds               0
# guests             0
# toiles             0
# bedrooms           0
# studios            0
# checkin          800
# checkout        2450
# dtype: int64

# %%
df['checkout'].value_counts()
# Out:
# checkout
# 11 00 am    4391
# 12 00 pm    2648
# 10 00 am    2622
# 9 00 am      186
# 1 00 pm      178
# 12 00 am      82
# 2 00 pm       72
# 3 00 pm       50
# 8 00 am       30
# 4 00 pm       18
# 5 00 pm       16
# 6 00 pm       15
# 11 00 pm      15
# 1 00 am       12
# 2 00 am        6
# 10 00 pm       4
# 7 00 am        3
# 3 00 am        3
# 8 00 pm        2
# 7 00 pm        1
# 4 00 am        1
# Name: count, dtype: int64

# %%
df['checkin'].value_counts()
# Out:
# checkin
# After 3 00 pm          2554
# After 2 00 pm          1545
# Flexible                926
# After 4 00 pm           650
# After 12 00 pm          644
#                        ...
# 10 00 am - 1 00 am        1
# 12 00 am - 2 00 am        1
# 10 00 pm - 12 00 am       1
# 8 00 am - 1 00 pm         1
# 11 00 am - 2 00 am        1
# Name: count, Length: 153, dtype: int64

# %%
check_in=(df['checkin'] == 'Flexible').value_counts()
check_in
# Out:
# checkin
# False    12805
# Name: count, dtype: int64

# %%
number_of_hosts=df['host_id'].value_counts()
#number_of_hosts.head(20)
hosts_with_multiple_property = number_of_hosts >= 2
hosts_with_multiple_property.value_counts()
# Out:
# count
# False    8923
# True     1452
# Name: count, dtype: int64

# %%
filtered_df = df[df['host_id'] == 386223873.0]
filtered_df.value_counts()
# Out:
# Unnamed: 0  id                  name                                                             rating  reviews  host_name  host_id      address                        features                                 amenities                                                                                                                                                                                              safety_rules                                                                                                                                         hourse_rules                                                                              img_links                                                                                                                                                                                                                                                                                                                                                     
# ...

# %%
df_price=df['price']
df_price.max()
df_price.min()
print(f"Max Rent:{df_price.max()}, Min Rent =: {df_price.min()}")
# Out:
# Max Rent:1907963, Min Rent =: 393

# %%
max_rent = df[df['price'] == 1907963]
max_rent
# Out:
#       Unnamed: 0                  id                               name  \
# 4488        4488  547559802034179497  38 MT 5 CABINS DELUXE MOTOR YACHT
#
#      rating reviews           host_name      host_id                address  \
# 4488    New       0  Important Yachting  374411260.0  Bodrum, Muğla, Turkey
#
#                                      features  \
# 4488  10 guests,5 bedrooms,7 beds,5 bathrooms
#
#                                               amenities  \
# 4488  Beach access,Kitchen,Wifi,Dedicated workspace,...
#
#                                            safety_rules  \
# 4488  󹀁,Airbnb's COVID-19 safety practices apply,Car...
#
#                                            hourse_rules  \
# 4488  Check-in: After 3:00 pm,Check out: 10:00 am,No...
#
#                                               img_links    price  country  \
# 4488  https://a0.muscache.com/im/pictures/miso/Hosti...  1907963   Turkey
#
# ...

# %%
min_rent = df[df['price'] == 393]
min_rent
# Out:
#       Unnamed: 0                  id  \
# 3071        3071  623499984203397321
#
#                                                   name rating reviews  \
# 3071  Beautiful  rooms with balcony , wifi and parking    New       2
#
#      host_name      host_id                          address  \
# 3071   Abhinav  353459955.0  Manali, Himachal Pradesh, India
#
#                                           features  \
# 3071  4 guests,1 bedroom,2 beds,1 private bathroom
#
#                                               amenities  \
# 3071  Kitchen,Wifi,Dedicated workspace,Free parking ...
#
#                                            safety_rules  \
# 3071  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                            hourse_rules  \
# 3071  Check-in: Flexible,Pets are allowed,󱤇,Smoking ...
#
#                                               img_links  price country  \
# 3071  https://a0.muscache.com/im/pictures/a9362b66-5...    393   India
#
# ...

# %%
df.hist(figsize=(12,20))
plt.show()

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

df.plot(kind="line", x="price", y="rating", figsize=(12, 8))

plt.show()

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

plt.figure(figsize=(12, 8))
plt.scatter(df['price'], df['rating'])
plt.xlabel('Price')
plt.ylabel('Rating')
plt.title('Rating vs. Price')
plt.show()

# %%
# df['rating'] = pd.to_numeric(df['rating'], errors='coerce')
print(df['rating'].value_counts())
print(df['rating'].isna().count())
df['rating'].min()
# Out:
# rating
# 5.00    2001
# 4.67     278
# 4.90     269
# 4.88     267
# 4.75     253
#         ...
# 4.38       1
# 4.48       1
# 4.20       1
# 4.26       1
# 4.31       1
# Name: count, Length: 76, dtype: int64
# 12805
# 3.0

# %%
df.head()
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
# 2           2  50699164                                  cottages sataplia
# 3           3  49871422                        Sapanca Breathable Bungalow
# 4           4  51245886                                      Bungalov Ev 2
#
#    rating reviews    host_name      host_id                   address  \
# 0    4.71      64    Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1     NaN       0        Fatih  386223873.0      Kaş, Antalya, Turkey
# 2    4.85      68       Giorgi  409690853.0          Imereti, Georgia
# 3    5.00      13        Melih  401873242.0  Sapanca, Sakarya, Turkey
# 4     NaN       0  Arp Sapanca  414884116.0  Sapanca, Sakarya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# ...
